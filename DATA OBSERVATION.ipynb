# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Data import
train_df = pd.read_csv("./Lightning7/Lighting7_TRAIN.txt", header=None)
test_df = pd.read_csv("./Lightning7/Lighting7_TEST.txt",header=None)
all_data = pd.concat([train_df, test_df]) #combining data to experiment with different train/test splits

# %%
#showing values by class
classes = {}
for i in range(7):
    classes[i] = all_data.loc[all_data[0]==i]
class_names = {x:y for x,y in zip(range(0,7),['CG', 'IR', 'SR', 'I', 'I2', 'KM', 'O'])}

# %%
#plot some representative examples together
for c in classes:
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))
    fig.suptitle(class_names[c]+" (label=%d)"%c, fontsize=16)
    for ax in axes:
        ax.plot(classes[c].sample(n=1).drop(0,axis=1).transpose().values)

# %%
#plot classes together
for i in range(10):
    plt.figure(i)
    for c in classes:
        plt.title("all classes")
        plt.plot(classes[c].sample(n=1).drop(0,axis=1).transpose().values, label=class_names[c])
        plt.legend(loc='upper left')
