# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Data import
train_df = pd.read_csv("./Lightning7/Lighting7_TRAIN.txt", header=None)
test_df = pd.read_csv("./Lightning7/Lighting7_TEST.txt",header=None)
all_data = pd.concat([train_df, test_df]) #combining data to experiment with different train/test splits

# %%
all_data.head()
# Out:
#    0        1        2        3        4        5        6        7    \
# 0    5 -0.61005 -0.61005 -0.61005 -0.61005 -0.61005 -0.61005 -0.61005
# 1    5 -0.89540 -0.89540 -0.89540 -0.89540 -0.89540 -0.89540 -0.89540
# 2    0 -0.76616 -0.76616 -0.76616 -0.76616 -0.76616 -0.76616 -0.76616
# 3    3 -0.46489 -0.46489 -0.46489 -0.46489 -0.46489 -0.46489 -0.46489
# 4    4 -0.43042 -0.43042 -0.43042 -0.43042 -0.43042 -0.43042 -0.43042
#
#        8        9     ...         310       311       312       313      314  \
# 0 -0.61005 -0.61005   ...    -0.22939 -0.208920 -0.265050 -0.233910 -0.32902
# 1 -0.89540 -0.89540   ...    -0.20851 -0.377340 -0.245030 -0.309300 -0.44780
# 2 -0.76616 -0.76616   ...    -0.17510  0.142970 -0.100740 -0.159350 -0.14953
# 3 -0.46489 -0.46489   ...    -0.05036  0.058392  0.085977 -0.025799 -0.12047
# 4 -0.43042 -0.43042   ...    -0.33869 -0.380040 -0.429820 -0.430420 -0.43042
#
#         315       316      317      318      319
# ...

# %%
#showing values by class
classes = {}
for i in range(7):
    classes[i] = all_data.loc[all_data[0]==i]

# %%
#plot some representative examples together
for c in classes:
    plt.figure(c)
    plt.title("Class %d"%c)
    plt.plot(classes[c].sample(n=1).drop(0,axis=1).transpose().values)

# %%
#plot classes together
for i in range(10):
    plt.figure(i)
    for c in classes:
        plt.title("all classes")
        plt.plot(classes[c].sample(n=1).drop(0,axis=1).transpose().values, label="Class %d"%c)
        plt.legend()
